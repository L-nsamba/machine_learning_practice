# %%
import numpy as np

# %% [markdown]
# **Error**: Where did we go wrong?

# %%
B = np.zeros(shape=(3,2)) # Fix to the shape since B will be a 3 x 2 when transposed
A =  [[1, 2, 6], [3, 4, 5]]

for row in range(len(A)):
  for col in range(len(A[0])): # Fix to column indexing
    B[col][row] = A[row][col] # Where the transposition happens
  print(B) # From 2 x 3 -> 3 x 2
# Out:
# [[1. 0.]
#  [2. 0.]
#  [6. 0.]]
# [[1. 3.]
#  [2. 4.]
#  [6. 5.]]
